# %%
#a=coef_ue1['R101']
ue1={
    'R101':10,
    'R102':10,
    'R103':7,
    'R104':7,
    'R105':0,
    'R106':5,
    'R107':0,
    'R108':6,
    'R109':0,
    'R110':5,
    'R111':4,
    'R112':2,
    'R113':5,
    'R114':5,
    'R115':0,
    'SAE11':20,
    'SAE12':20,
    'SAE13':0,
    'SAE14':0,
    'SAE15':0,
    'SAE16':7,
    }
list_ue1 = [20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20,]

for i in range(1, 22):
    ue1.values()*liste_ue1.values()
    
moy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 28
#      25 list_ue1 = [20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20,]
#      27 for i in range(1, 22):
# ---> 28     ue1.values()*liste_ue1.values()
#      30 moy()
#
# NameError: name 'liste_ue1' is not defined
