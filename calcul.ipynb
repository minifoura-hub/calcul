# %%
ue1note={
    "R101":10,
    "R102":10,
    "R103":10,
    "R104":10
}
ue1coef={
    "R101":5,
    "R102":5,
    "R103":5,
    "R104":5,
    "R105":5
}
    
def calcul():
    for element in (ue1note, ue1coef) :
        total_note = 0
        total_coef = 0
        total_note += ue1note["note"]* ue1coef["coef"]
        total_coef += sum[ue1note["coef"]]
        moyenne_ue1 = total_note / total_coef
    return(moyenne_ue1)

# %%
calcul()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 calcul()
#
# Cell In[41], line 19, in calcul()
#      17 total_note = 0
#      18 total_coef = 0
# ---> 19 total_note += ue1note["note"]* ue1coef["coef"]
#      20 total_coef += sum[ue1note["coef"]]
#      21 moyenne_ue1 = total_note / total_coef
#
# KeyError: 'note'
